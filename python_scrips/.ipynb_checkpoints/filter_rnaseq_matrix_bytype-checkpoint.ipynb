# %% [markdown]
# ## Filter sarcoma UPS

# %% [markdown]
# Filter from all sarcomas

# %%
import pandas as pd

# %%
counts = pd.read_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/rnaseq/merged_annotations_sarcoma_rnaseq.csv')

# %%
meta = pd.read_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/rnaseq/quartiles_all_sarcoma_metadata.txt')

# %%
meta_ups
# Out:
#                                               filename patient_barcode  \
# 7    09e38d91-d811-4b29-b40a-e5a79d236043.htseq.counts    TCGA-DX-A6B8
# 13   0f8d7e4c-f855-4c7d-8a1b-5637f2b5cbc5.htseq.counts    TCGA-3B-A9I3
# 17   12a2d93e-8567-4a55-a3f3-4c94c51ffb6a.htseq.counts    TCGA-IE-A3OV
# 18   138485c1-4e31-4d40-a1c0-af9448f4b650.htseq.counts    TCGA-3B-A9HR
# 20   16a96f90-6ce8-433f-a409-39a36fe354b2.htseq.counts    TCGA-K1-A6RV
# ..                                                 ...             ...
# 238  f701554c-c851-4bfb-8bd1-18f0b268ac68.htseq.counts    TCGA-DX-A3U8
# 241  fb783ec9-4ca1-4354-bb51-29b5bbb909b3.htseq.counts    TCGA-3B-A9HZ
# 242  fc2da9a1-773c-4b3a-bfd6-7e4fb911e536.htseq.counts    TCGA-QQ-A5VC
# 246  feb05cdb-3124-4020-96cd-3369d7657d56.htseq.counts    TCGA-DX-A8BZ
# 247  ff0f98ba-a00f-4dc5-ac2d-9f0d1cd38366.htseq.counts    TCGA-3B-A9HT
#
#                           bcr_sample_uuid     histological_type  \
# ...

# %%
meta_ups.to_csv('meta_Leio.tsv', index = None, sep = '\t')

# %%
counts_ups = counts[counts.columns.intersection(meta_ups['filename'])]

# %%
counts_ups['ensembl'] = counts['ensembl']
# Out:
# <ipython-input-53-dcde01ad8ff2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   counts_ups['ensembl'] = counts['ensembl']

# %%
counts_ups.to_csv('counts_Leio.tsv', index = None, sep = '\t')

# %%
counts_ups
# Out:
#        46f970d5-057a-41dc-839d-3928a47d031b.htseq.counts  \
# 0                                                    757
# 1                                                     12
# 2                                                   1473
# 3                                                    636
# 4                                                    498
# ...                                                  ...
# 60483                                            3632277
# 60484                                            2020831
# 60485                                                  0
# 60486                                                  0
# 60487                                           10662436
#
#        2b66a8a5-1e0a-4a4a-beb7-b2273b2ffb05.htseq.counts  \
# 0                                                    618
# 1                                                     62
# 2                                                   1000
# ...
