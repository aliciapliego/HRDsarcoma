# %% [markdown]
# ## Filter sarcoma UPS

# %% [markdown]
# Filter from all sarcomas

# %%
import pandas as pd

# %%
counts = pd.read_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/rnaseq/all_counts_filter.csv')
counts = counts.rename(columns = {'patient_barcode': 'Case_ID'})

# %%
counts
# Out:
#                       ensembl  \
# 0             ENSG00000000003
# 1             ENSG00000000005
# 2             ENSG00000000419
# 3             ENSG00000000457
# 4             ENSG00000000460
# ...                       ...
# 60483            __no_feature
# 60484             __ambiguous
# 60485         __too_low_aQual
# 60486           __not_aligned
# 60487  __alignment_not_unique
#
#        fca51e84-4783-4e3a-b4a0-85371ce84e43.htseq.counts  \
# 0                                                   2608
# 1                                                   1643
# 2                                                   1903
# 3                                                   1147
# 4                                                    447
# ...                                                  ...
# 60483                                            3735457
# 60484                                            2633210
# 60485                                                  0
# ...

# %%
counts.head(2)
# Out:
#            ensembl  fca51e84-4783-4e3a-b4a0-85371ce84e43.htseq.counts  \
# 0  ENSG00000000003                                               2608
# 1  ENSG00000000005                                               1643
#
#    602936ca-5d14-400f-9503-994fcb99a2da.htseq.counts  \
# 0                                               1531
# 1                                                 50
#
#    cc6a2e77-2220-4046-b653-e8b4f9dd39c7.htseq.counts  \
# 0                                                568
# 1                                                 43
#
#    5240afee-fc3e-4729-9928-588cdbea28b3.htseq.counts  \
# 0                                               4220
# 1                                               4056
#
#    836e295d-d1e1-48f1-98c8-04d649fbd796.htseq.counts  \
# 0                                               1147
# 1                                                  1
#
#    46f970d5-057a-41dc-839d-3928a47d031b.htseq.counts  \
# ...

# %%
meta = pd.read_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/rnaseq/quartiles_all_sarcoma_metadata.txt', sep = '\t')

# %%
meta.head(2)
# Out:
#                                             filename patient_barcode  \
# 0  09ab0fec-f6bf-4c7e-bb92-d9de298c42eb.htseq.counts    TCGA-DX-A3U6
# 1  0cfeaebb-ab33-4711-9c86-f15110041ba9.htseq.counts    TCGA-3B-A9HO
#
#                         bcr_sample_uuid             histological_type  \
# 0  ACEA4025-F740-4A60-AD51-EAF61964256B  Dedifferentiated liposarcoma
# 1  697BD072-F6BD-4545-9C30-2C61ADE688FE  Dedifferentiated liposarcoma
#
#    days_to_sample_procurement path_confirm_report_attached  \
# 0                        67.0                          YES
# 1                        56.0                          YES
#
#   method_of_sample_procurement other_method_of_sample_procurement  \
# 0           Surgical Resection                   [Not Applicable]
# 1           Surgical Resection                   [Not Applicable]
#
#          other_vessel_used vessel_used  ...                               md5  \
# 0         [Not Applicable]    Cryomold  ...  cd0d89ffe0bb7c58a4dbe9bd58cf0065
# ...

# %%
counts_ups = counts[counts.columns.intersection(meta['filename'])]

# %%
counts_ups = counts_ups.set_index(counts['ensembl'])

# %%
counts_ups.to_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/rnaseq/quartiles_all_sarcoma_counts.txt', sep = '\t')

# %%
meta = meta.set_index('filename')
meta = meta.loc[counts_ups.columns]
meta
# Out:
#                                                   patient_barcode  \
# fca51e84-4783-4e3a-b4a0-85371ce84e43.htseq.counts    TCGA-WK-A8XT
# 602936ca-5d14-400f-9503-994fcb99a2da.htseq.counts    TCGA-IE-A4EJ
# 836e295d-d1e1-48f1-98c8-04d649fbd796.htseq.counts    TCGA-DX-A240
# bffe7bae-47a4-43f0-b071-93ce7337d7fb.htseq.counts    TCGA-HS-A5N8
# 5b210841-b44b-476d-837a-d21bfcc984b3.htseq.counts    TCGA-DX-AB2G
# ...                                                           ...
# fd700b77-843b-49a6-800d-545b5f2bab90.htseq.counts    TCGA-SI-A71O
# 44db1348-8a8c-4ef2-99e9-e5a13a9c81ec.htseq.counts    TCGA-DX-A7EQ
# d70b05b6-aef5-43f6-b8f6-d670c5672478.htseq.counts    TCGA-DX-A6Z0
# f10cc48c-4566-41fd-8dbf-66393ee09d70.htseq.counts    TCGA-QQ-A8VH
# ecdb44a4-9a1c-4cf6-94b2-5b437eef2361.htseq.counts    TCGA-IE-A4EK
#
#                                                                         bcr_sample_uuid  \
# ...

# %% [markdown]
# ## Cluster analysis

# %%
cluster = pd.read_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/rnaseq/clusters_all_sarcoma.tsv', sep = '\t')

# %%
meta_cluster = meta.merge(cluster, right_on = 'gene', left_on = meta.index)
meta_cluster.to_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/cluster_annotations_all_sarcoma.tsv', sep = '\t')

# %%
treatment = pd.read_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/sarc_tcga_pub_clinical_data.tsv', sep = '\t')

# %%
treatment
# Out:
#           Study ID    Patient ID        Sample ID  Diagnosis Age  \
# 0    sarc_tcga_pub  TCGA-3B-A9HI  TCGA-3B-A9HI-01             68
# 1    sarc_tcga_pub  TCGA-3B-A9HL  TCGA-3B-A9HL-01             67
# 2    sarc_tcga_pub  TCGA-3B-A9HO  TCGA-3B-A9HO-01             75
# 3    sarc_tcga_pub  TCGA-3B-A9HP  TCGA-3B-A9HP-01             57
# 4    sarc_tcga_pub  TCGA-3B-A9HQ  TCGA-3B-A9HQ-01             66
# ..             ...           ...              ...            ...
# 201  sarc_tcga_pub  TCGA-X6-A8C5  TCGA-X6-A8C5-01             63
# 202  sarc_tcga_pub  TCGA-X6-A8C7  TCGA-X6-A8C7-01             24
# 203  sarc_tcga_pub  TCGA-X9-A971  TCGA-X9-A971-01             52
# 204  sarc_tcga_pub  TCGA-Z4-AAPF  TCGA-Z4-AAPF-01             35
# 205  sarc_tcga_pub  TCGA-Z4-AAPG  TCGA-Z4-AAPG-01             64
#
#      AMP 12q15 CDK4  AMP 12q15 DDIT3  AMP 12q15 FRS2  AMP 12q15 HMGA2  \
# 0            -0.105           -0.154          -0.105           -0.105
# ...

# %%
treatment_meta = treatment.merge(meta_cluster, left_on = 'Patient ID', right_on = 'patient_barcode')
treatment_meta.to_csv('/Users/aliciapliego/Projects/HRDsarcoma/data/cluster_annotations_all_sarcoma_clinicaldata.tsv', sep = '\t')
#treatment_meta[['Case_ID', 'Type', 'HRD-sum', 'HRD34_x', 'treatment', 'total_cin', 'cluster', 'other_dx', 'consent_or_death_status', 'site_of_disease']]

# %% [markdown]
# ### Filter by sarcoma type

# %%
meta_ups.to_csv('meta_Leio.tsv', index = None, sep = '\t')

# %%
counts_ups = counts[counts.columns.intersection(meta_ups['filename'])]

# %%
counts_ups['ensembl'] = counts['ensembl']
# Out:
# <ipython-input-53-dcde01ad8ff2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   counts_ups['ensembl'] = counts['ensembl']

# %%
counts_ups.to_csv('counts_Leio.tsv', index = None, sep = '\t')

# %%
counts_ups
# Out:
#        46f970d5-057a-41dc-839d-3928a47d031b.htseq.counts  \
# 0                                                    757
# 1                                                     12
# 2                                                   1473
# 3                                                    636
# 4                                                    498
# ...                                                  ...
# 60483                                            3632277
# 60484                                            2020831
# 60485                                                  0
# 60486                                                  0
# 60487                                           10662436
#
#        2b66a8a5-1e0a-4a4a-beb7-b2273b2ffb05.htseq.counts  \
# 0                                                    618
# 1                                                     62
# 2                                                   1000
# ...
